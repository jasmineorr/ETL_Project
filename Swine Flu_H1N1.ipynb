# %%
import pandas as pd
from sqlalchemy import create_engine
import pymongo

# %%
swine_file = "Resources/Pandemic_(H1N1)_2009.csv"
swine_data_df = pd.read_csv(swine_file, encoding='ISO-8859-1')
swine_data_df.head()
# Out:
#                Country  Cases  Deaths    Update Time
# 0              Algeria      5     0.0  7/6/2009 9:00
# 1  Antigua and Barbuda      2     0.0  7/6/2009 9:00
# 2            Argentina   2485    60.0  7/6/2009 9:00
# 3            Australia   5298    10.0  7/6/2009 9:00
# 4              Austria     19     0.0  7/6/2009 9:00

# %%
latestDate = "7/6/2009 9:00"

# %%
swine_data_df.sort_values(by="Country", ascending=True)
# .groupby("Country").value_counts(["Cases","Deaths"])
# Out:
#                      Country  Cases  Deaths     Update Time
# 0                    Algeria      5     0.0   7/6/2009 9:00
# 383                  Algeria      2     0.0  6/29/2009 9:00
# 721                  Algeria      1     0.0  6/22/2009 7:00
# 262                  Algeria      2     0.0   7/1/2009 9:00
# 612                  Algeria      2     0.0  6/24/2009 7:00
# ..                       ...    ...     ...             ...
# 82        Netherlands, Aruba      5     0.0   7/6/2009 9:00
# 45        New Caledonia, FOC     12     0.0   7/6/2009 9:00
# 127              Puerto Rico     18     0.0   7/6/2009 9:00
# 46         Saint Martin, FOC      1     0.0   7/6/2009 9:00
# 128           Virgin Islands      1     0.0   7/6/2009 9:00
#
# [1822 rows x 4 columns]

# %%
swine_data_dfClean = swine_data_df.loc[swine_data_df['Update Time'] == latestDate]
swine_data_dfClean
# Out:
#                       Country  Cases  Deaths    Update Time
# 0                     Algeria      5     0.0  7/6/2009 9:00
# 1         Antigua and Barbuda      2     0.0  7/6/2009 9:00
# 2                   Argentina   2485    60.0  7/6/2009 9:00
# 3                   Australia   5298    10.0  7/6/2009 9:00
# 4                     Austria     19     0.0  7/6/2009 9:00
# ..                        ...    ...     ...            ...
# 131                 Venezuela    206     0.0  7/6/2009 9:00
# 132                  Viet Nam    181     0.0  7/6/2009 9:00
# 133  West Bank and Gaza Strip     60     0.0  7/6/2009 9:00
# 134                     Yemen      8     0.0  7/6/2009 9:00
# 135               Grand Total  94512   429.0  7/6/2009 9:00
#
# [136 rows x 4 columns]

# %%
#swine_data_dfClean = swine_data_dfClean.drop(columns=["Update Time"])
swine_data_dfSum = swine_data_dfClean.groupby("Country")['Cases','Deaths'].sum()
swine_data_dfSum.head()
# Out:
#                      Cases  Deaths
# Country
# Algeria                  5     0.0
# Antigua and Barbuda      2     0.0
# Argentina             2485    60.0
# Australia             5298    10.0
# Austria                 19     0.0

# %% [markdown]
# ## Create database connection

# %%
connection_string = "postgres:postgres@localhost:5432/ETL_Project"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ...

# %% [markdown]
# ## Load DataFrames into database

# %%
swine_data_dfSum_transformed.to_sql(name='swineFlu', con=engine, if_exists='replace', index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-edf9ae465886> in <module>
# ----> 1 swine_data_dfSum_transformed.to_sql(name='swineFlu', con=engine, if_exists='append', index=True)
#
# NameError: name 'swine_data_dfSum_transformed' is not defined
